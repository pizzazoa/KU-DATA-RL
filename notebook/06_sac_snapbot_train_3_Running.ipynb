# %% [markdown]
# ### `Soft Actor-Critic` using `Snapbot`

# %%
import sys,mujoco
import numpy as np
import matplotlib.pyplot as plt
sys.path.append('../package/helper/')
sys.path.append('../package/mujoco_usage/')
sys.path.append('../package/gym/')
sys.path.append('../package/rl/')
from mujoco_parser import *
from slider import *
from utility import *
from snapbot_env_3_Running import *
from sac import *
np.set_printoptions(precision=2,suppress=True,linewidth=100)
plt.rc('xtick',labelsize=6); plt.rc('ytick',labelsize=6)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
print ("Ready.")
# Out:
# Ready.

# %% [markdown]
# #### Parse `Snapbot` gym

# %%
xml_path = '../asset/snapbot/scene_snapbot.xml'
env = MuJoCoParserClass(name='Snapbot_Running',rel_xml_path=xml_path,verbose=True)
gym = SnapbotGymClass(
    env = env,
    HZ  = 50,
    history_total_sec = 0.2,
    history_intv_sec  = 0.1,
    VERBOSE =True,
)
print ("Ready.")
# Out:
# name:[Snapbot_Running] dt:[0.002] HZ:[500]
# n_qpos:[25] n_qvel:[24] n_qacc:[24] n_ctrl:[8]
#
# n_body:[24]
#  [0/24] [world] mass:[0.00]kg
#  [1/24] [torso] mass:[0.24]kg
#  [2/24] [Camera_module_1] mass:[0.06]kg
#  [3/24] [Camera_module_2] mass:[0.06]kg
#  [4/24] [Leg_module_1_1] mass:[0.06]kg
#  [5/24] [Leg_module_1_2] mass:[0.08]kg
#  [6/24] [Leg_module_1_3] mass:[0.02]kg
#  [7/24] [Leg_module_1_4] mass:[0.01]kg
#  [8/24] [Leg_module_1_4bar] mass:[0.01]kg
#  [9/24] [Leg_module_2_1] mass:[0.06]kg
#  [10/24] [Leg_module_2_2] mass:[0.08]kg
#  [11/24] [Leg_module_2_3] mass:[0.02]kg
#  [12/24] [Leg_module_2_4] mass:[0.01]kg
#  [13/24] [Leg_module_2_4bar] mass:[0.01]kg
#  [14/24] [Leg_module_4_1] mass:[0.06]kg
#  [15/24] [Leg_module_4_2] mass:[0.08]kg
#  [16/24] [Leg_module_4_3] mass:[0.02]kg
#  [17/24] [Leg_module_4_4] mass:[0.01]kg
#  [18/24] [Leg_module_4_4bar] mass:[0.01]kg
#  [19/24] [Leg_module_5_1] mass:[0.06]kg
#  [20/24] [Leg_module_5_2] mass:[0.08]kg
#  [21/24] [Leg_module_5_3] mass:[0.02]kg
#  [22/24] [Leg_module_5_4] mass:[0.01]kg
#  [23/24] [Leg_module_5_4bar] mass:[0.01]kg
# body_total_mass:[1.10]kg
#
# n_geom:[24]
# geom_names:['floor', 'body', 'camera_module_1', 'camera_module_2', 'leg_module_1_1', 'leg_module_1_2', 'leg_module_1_3', 'leg_module_1_4', 'leg_module_1_4bar', 'leg_module_2_1', 'leg_module_2_2', 'leg_module_2_3', 'leg_module_2_4', 'leg_module_2_4bar', 'leg_module_4_1', 'leg_module_4_2', 'leg_module_4_3', 'leg_module_4_4', 'leg_module_4_4bar', 'leg_module_5_1', 'leg_module_5_2', 'leg_module_5_3', 'leg_module_5_4', 'leg_module_5_4bar']
#
# n_joint:[19]
#  [0/19] [free] axis:[0. 0. 1.]
#  [1/19] [camera_1] axis:[0. 0. 1.]
#  [2/19] [camera_2] axis:[ 0.42 -0.91  0.  ]
#  [3/19] [leg_1_2] axis:[0. 1. 0.]
#  [4/19] [leg_1_3] axis:[1. 0. 0.]
#  [5/19] [leg_1_4] axis:[1. 0. 0.]
#  [6/19] [leg_1_4bar] axis:[1. 0. 0.]
#  [7/19] [leg_2_2] axis:[0. 1. 0.]
#  [8/19] [leg_2_3] axis:[1. 0. 0.]
#  [9/19] [leg_2_4] axis:[1. 0. 0.]
#  [10/19] [leg_2_4bar] axis:[1. 0. 0.]
#  [11/19] [leg_4_2] axis:[0. 1. 0.]
#  [12/19] [leg_4_3] axis:[1. 0. 0.]
#  [13/19] [leg_4_4] axis:[1. 0. 0.]
#  [14/19] [leg_4_4bar] axis:[1. 0. 0.]
#  [15/19] [leg_5_2] axis:[0. 1. 0.]
#  [16/19] [leg_5_3] axis:[1. 0. 0.]
#  [17/19] [leg_5_4] axis:[1. 0. 0.]
#  [18/19] [leg_5_4bar] axis:[1. 0. 0.]
#
# n_dof:[24] (=number of rows of Jacobian)
#  [0/24] [None] attached joint:[free] body:[torso]
#  [1/24] [None] attached joint:[free] body:[torso]
#  [2/24] [None] attached joint:[free] body:[torso]
#  [3/24] [None] attached joint:[free] body:[torso]
#  [4/24] [None] attached joint:[free] body:[torso]
#  [5/24] [None] attached joint:[free] body:[torso]
#  [6/24] [None] attached joint:[camera_1] body:[Camera_module_1]
#  [7/24] [None] attached joint:[camera_2] body:[Camera_module_2]
#  [8/24] [None] attached joint:[leg_1_2] body:[Leg_module_1_2]
#  [9/24] [None] attached joint:[leg_1_3] body:[Leg_module_1_3]
#  [10/24] [None] attached joint:[leg_1_4] body:[Leg_module_1_4]
#  [11/24] [None] attached joint:[leg_1_4bar] body:[Leg_module_1_4bar]
#  [12/24] [None] attached joint:[leg_2_2] body:[Leg_module_2_2]
#  [13/24] [None] attached joint:[leg_2_3] body:[Leg_module_2_3]
#  [14/24] [None] attached joint:[leg_2_4] body:[Leg_module_2_4]
#  [15/24] [None] attached joint:[leg_2_4bar] body:[Leg_module_2_4bar]
#  [16/24] [None] attached joint:[leg_4_2] body:[Leg_module_4_2]
#  [17/24] [None] attached joint:[leg_4_3] body:[Leg_module_4_3]
#  [18/24] [None] attached joint:[leg_4_4] body:[Leg_module_4_4]
#  [19/24] [None] attached joint:[leg_4_4bar] body:[Leg_module_4_4bar]
#  [20/24] [None] attached joint:[leg_5_2] body:[Leg_module_5_2]
#  [21/24] [None] attached joint:[leg_5_3] body:[Leg_module_5_3]
#  [22/24] [None] attached joint:[leg_5_4] body:[Leg_module_5_4]
#  [23/24] [None] attached joint:[leg_5_4bar] body:[Leg_module_5_4bar]
#
# Free joint information. n_free_joint:[1]
#  [0/1] [free] body_name_attached:[torso]
#
# Revolute joint information. n_rev_joint:[18]
#  [0/18] [camera_1] range:[0.000]~[0.000]
#  [1/18] [camera_2] range:[-3.140]~[0.000]
#  [2/18] [leg_1_2] range:[-0.900]~[0.900]
#  [3/18] [leg_1_3] range:[-0.700]~[0.700]
#  [4/18] [leg_1_4] range:[0.000]~[0.000]
#  [5/18] [leg_1_4bar] range:[0.000]~[0.000]
#  [6/18] [leg_2_2] range:[-0.900]~[0.900]
#  [7/18] [leg_2_3] range:[-0.700]~[0.700]
#  [8/18] [leg_2_4] range:[0.000]~[0.000]
#  [9/18] [leg_2_4bar] range:[0.000]~[0.000]
#  [10/18] [leg_4_2] range:[-0.900]~[0.900]
#  [11/18] [leg_4_3] range:[-0.700]~[0.700]
#  [12/18] [leg_4_4] range:[0.000]~[0.000]
#  [13/18] [leg_4_4bar] range:[0.000]~[0.000]
#  [14/18] [leg_5_2] range:[-0.900]~[0.900]
#  [15/18] [leg_5_3] range:[-0.700]~[0.700]
#  [16/18] [leg_5_4] range:[0.000]~[0.000]
#  [17/18] [leg_5_4bar] range:[0.000]~[0.000]
#
# Prismatic joint information. n_pri_joint:[0]
#
# Control information. n_ctrl:[8]
#  [0/8] [actuator_1_2] range:[-5.000]~[5.000] gear:[1.00] type:[JOINT]
#  [1/8] [actuator_1_3] range:[-5.000]~[5.000] gear:[1.00] type:[JOINT]
#  [2/8] [actuator_2_2] range:[-5.000]~[5.000] gear:[1.00] type:[JOINT]
#  [3/8] [actuator_2_3] range:[-5.000]~[5.000] gear:[1.00] type:[JOINT]
#  [4/8] [actuator_4_2] range:[-5.000]~[5.000] gear:[1.00] type:[JOINT]
#  [5/8] [actuator_4_3] range:[-5.000]~[5.000] gear:[1.00] type:[JOINT]
#  [6/8] [actuator_5_2] range:[-5.000]~[5.000] gear:[1.00] type:[JOINT]
#  [7/8] [actuator_5_3] range:[-5.000]~[5.000] gear:[1.00] type:[JOINT]
#
# n_sensor:[8]
# sensor_names:['touchsensor_1_4', 'touchsensor_2_4', 'touchsensor_4_4', 'touchsensor_5_4', 'touchsensor_1_2', 'touchsensor_2_2', 'touchsensor_4_2', 'touchsensor_5_2']
# n_site:[8]
# site_names:['sensorsurf_1_2', 'sensorsurf_1_4', 'sensorsurf_2_2', 'sensorsurf_2_4', 'sensorsurf_4_2', 'sensorsurf_4_4', 'sensorsurf_5_2', 'sensorsurf_5_4']
# [Snapbot_Running] Instantiated
#    [info] dt:[0.0200] HZ:[50], env-HZ:[500], mujoco_nstep:[10], state_dim:[35], o_dim:[70], a_dim:[8]
#    [history] total_sec:[0.20]sec, n:[10], intv_sec:[0.10]sec, intv_tick:[5]
#    [history] ticks:[0 5]
# Ready.

# %% [markdown]
# #### `SAC` configuration

# %%
n_episode         = 2500 # number of total episodes (rollouts)
max_epi_sec       = 5.0 # maximum episode length in second (IMPORTANT)
max_epi_tick      = int(max_epi_sec*gym.HZ) # maximum episode length in tick
n_warmup_epi      = 10 # number of warm-up episodes
buffer_limit      = 50000 # 50000
buffer_warmup     = buffer_limit // 5
init_alpha        = 0.1
max_torque        = 2.0
# Update
lr_actor          = 0.0005 # 0.0002
lr_alpha          = 0.0001 # 0.0003
lr_critic         = 0.0001
n_update_per_tick = 1 # number of updates per tick
batch_size        = 512
gamma             = 0.99
tau               = 0.005
# Debug
print_every       = 50
eval_every        = 50
save_every        = 50
RENDER_EVAL       = False # False
print ("n_episode:[%d], max_epi_sec:[%.2f], max_epi_tick:[%d]"%
       (n_episode,max_epi_sec,max_epi_tick))
print ("n_warmup_epi:[%d], buffer_limit:[%.d], buffer_warmup:[%d]"%
       (n_warmup_epi,buffer_limit,buffer_warmup))
# Out:
# n_episode:[2500], max_epi_sec:[5.00], max_epi_tick:[250]
# n_warmup_epi:[10], buffer_limit:[50000], buffer_warmup:[10000]

# %% [markdown]
# #### Initialize networks

# %%
device = 'cpu' # cpu / mps / cuda
replay_buffer = ReplayBufferClass(buffer_limit, device=device)
actor_arg = {'obs_dim':gym.o_dim,'h_dims':[256,256],'out_dim':gym.a_dim,
             'max_out':max_torque,'init_alpha':init_alpha,'lr_actor':lr_actor,
             'lr_alpha':lr_alpha,'device':device}
critic_arg = {'obs_dim':gym.o_dim,'a_dim':gym.a_dim,'h_dims':[256,256],'out_dim':1,
              'lr_critic':lr_critic,'device':device}
actor           = ActorClass(**actor_arg).to(device)
critic_one      = CriticClass(**critic_arg).to(device)
critic_two      = CriticClass(**critic_arg).to(device)
critic_one_trgt = CriticClass(**critic_arg).to(device)
critic_two_trgt = CriticClass(**critic_arg).to(device)
print ("Ready.")
# Out:
# Ready.

# %%
# Modify floor friction priority
env.model.geom('floor').priority = 1 # 0=>1
print ("Floor priority:%s"%(env.model.geom('floor').priority))
gym.env.ctrl_ranges[:,0] = -max_torque
gym.env.ctrl_ranges[:,1] = +max_torque
print ("gym.env.ctrl_ranges:\n",gym.env.ctrl_ranges)
# Out:
# Floor priority:[1]
# gym.env.ctrl_ranges:
#  [[-2.  2.]
#  [-2.  2.]
#  [-2.  2.]
#  [-2.  2.]
#  [-2.  2.]
#  [-2.  2.]
#  [-2.  2.]
#  [-2.  2.]]

# %% [markdown]
# #### Train using `SAC`

# %%
REMOVE_PREV_FILES = False # remove previous files

# Loop
np.random.seed(seed=0) # fix seed
print ("Start training.")
for epi_idx in range(n_episode+1): # for each episode
    zero_to_one = epi_idx/n_episode
    one_to_zero = 1-zero_to_one
    # Reset gym
    s = gym.reset()
    # Loop
    USE_RANDOM_POLICY = (np.random.rand()<(0.1*one_to_zero)) or (epi_idx < n_warmup_epi)
    reward_total,reward_sideway = 0.0,0.0
    for tick in range(max_epi_tick): # for each tick in an episode
        if USE_RANDOM_POLICY:
            a_np = gym.sample_action()
        else:
            a,log_prob = actor(np2torch(s,device=device))
            a_np = torch2np(a)
        # Step
        s_prime,reward,done,info = gym.step(a_np,max_time=max_epi_sec)
        replay_buffer.put((s,a_np,reward,s_prime,done))
        reward_total += reward 
        reward_sideway += info['r_sideway']
        s = s_prime
        if done is True: break # terminate condition
        
        # Replay buffer
        if replay_buffer.size() > buffer_warmup:
             for _ in range(n_update_per_tick): 
                mini_batch = replay_buffer.sample(batch_size)
                # Update critics
                td_target = get_target(
                    actor,
                    critic_one_trgt,
                    critic_two_trgt,
                    gamma      = gamma,
                    mini_batch = mini_batch,
                    device     = device,
                )
                critic_one.train(td_target,mini_batch)
                critic_two.train(td_target,mini_batch)
                # Update actor
                actor.train(
                    critic_one,
                    critic_two,
                    target_entropy = -gym.a_dim,
                    mini_batch     = mini_batch,
                )
                # Soft update of critics
                critic_one.soft_update(tau=tau,net_target=critic_one_trgt)
                critic_two.soft_update(tau=tau,net_target=critic_two_trgt)

    # Compute y_diff
    y_diff = gym.env.get_p_body('torso')[1]
    
    # Print
    if (epi_idx%print_every)==0:
        epi_tick = tick
        print ("[%d/%d][%.1f%%]"%(epi_idx,n_episode,100.0*(epi_idx/n_episode)))
        print ("  reward:[%.1f] y_diff:[%.3f] epi_len:[%d/%d] buffer_size:[%d] alpha:[%.2f]"%
               (reward_total,y_diff,epi_tick,max_epi_tick,
                replay_buffer.size(),actor.log_alpha.exp()))
    
    # Evaluation
    if (epi_idx%eval_every)==0:
        if RENDER_EVAL: gym.init_viewer()
        s = gym.reset()
        reward_total = 0.0
        for tick in range(max_epi_tick):
            a,_ = actor(np2torch(s,device=device),SAMPLE_ACTION=False)
            s_prime,reward,done,info = gym.step(torch2np(a),max_time=max_epi_sec)
            reward_total += reward
            if RENDER_EVAL and ((tick%5) == 0):
                gym.render(
                    TRACK_TORSO      = True,
                    PLOT_WORLD_COORD = True,
                    PLOT_TORSO_COORD = True,
                    PLOT_SENSOR      = True,
                    PLOT_CONTACT     = True,
                    PLOT_TIME        = True,
                )
            s = s_prime
            if RENDER_EVAL:
                if not gym.is_viewer_alive(): break
        if RENDER_EVAL: gym.close_viewer()
        y_diff = gym.env.get_p_body('torso')[1]
        print ("  [Eval] reward:[%.3f] y_diff:[%.3f] epi_len:[%d/%d]"%
               (reward_total,y_diff,tick,max_epi_tick))

    # Save network
    if (epi_idx%save_every)==0:
        pth_path = './result/weights/sac_%s/episode_%d.pth'%(gym.name.lower(),epi_idx)
        dir_path = os.path.dirname(pth_path)
        if not os.path.exists(dir_path): os.makedirs(dir_path)
        if (epi_idx == 0) and REMOVE_PREV_FILES: # remove all existing files
            files = os.listdir(path=dir_path)
            print ("  [Save] Remove existing [%d] pth files."%(len(files)))
            for file in files: os.remove(os.path.join(dir_path,file))
        torch.save(actor.state_dict(),pth_path)
        print ("  [Save] [%s] saved."%(pth_path))

print ("Done.")
# Out:
# Start training.
# [0/2500][0.0%]
#   reward:[-140.7] y_diff:[-0.209] epi_len:[249/250] buffer_size:[250] alpha:[0.10]
#   [Eval] reward:[3.514] y_diff:[-0.054] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_0.pth] saved.
# [50/2500][2.0%]
#   reward:[3.1] y_diff:[0.065] epi_len:[249/250] buffer_size:[12388] alpha:[0.08]
#   [Eval] reward:[-19.048] y_diff:[0.063] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_50.pth] saved.
# [100/2500][4.0%]
#   reward:[-300.8] y_diff:[0.527] epi_len:[249/250] buffer_size:[24530] alpha:[0.03]
#   [Eval] reward:[-21.517] y_diff:[0.325] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_100.pth] saved.
# [150/2500][6.0%]
#   reward:[7.2] y_diff:[0.089] epi_len:[249/250] buffer_size:[35157] alpha:[0.01]
#   [Eval] reward:[-1446.301] y_diff:[-0.068] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_150.pth] saved.
# [200/2500][8.0%]
#   reward:[3.9] y_diff:[0.039] epi_len:[249/250] buffer_size:[47594] alpha:[0.00]
#   [Eval] reward:[4.237] y_diff:[0.073] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_200.pth] saved.
# [250/2500][10.0%]
#   reward:[11.4] y_diff:[0.116] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-30.236] y_diff:[0.120] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_250.pth] saved.
# [300/2500][12.0%]
#   reward:[-12.9] y_diff:[0.106] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[9.613] y_diff:[0.123] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_300.pth] saved.
# [350/2500][14.0%]
#   reward:[5.8] y_diff:[0.065] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-60.259] y_diff:[0.084] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_350.pth] saved.
# [400/2500][16.0%]
#   reward:[-6.4] y_diff:[0.155] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-28.781] y_diff:[0.106] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_400.pth] saved.
# [450/2500][18.0%]
#   reward:[8.7] y_diff:[0.244] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-57.582] y_diff:[0.386] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_450.pth] saved.
# [500/2500][20.0%]
#   reward:[5.2] y_diff:[0.130] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[7.155] y_diff:[0.123] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_500.pth] saved.
# [550/2500][22.0%]
#   reward:[12.3] y_diff:[0.197] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[13.469] y_diff:[0.147] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_550.pth] saved.
# [600/2500][24.0%]
#   reward:[20.4] y_diff:[0.323] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[15.484] y_diff:[0.225] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_600.pth] saved.
# [650/2500][26.0%]
#   reward:[-39.9] y_diff:[0.361] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-29.537] y_diff:[0.130] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_650.pth] saved.
# [700/2500][28.0%]
#   reward:[7.7] y_diff:[0.124] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[4.101] y_diff:[0.199] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_700.pth] saved.
# [750/2500][30.0%]
#   reward:[-119.7] y_diff:[0.019] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-14.743] y_diff:[0.318] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_750.pth] saved.
# [800/2500][32.0%]
#   reward:[13.8] y_diff:[0.412] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[19.114] y_diff:[0.369] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_800.pth] saved.
# [850/2500][34.0%]
#   reward:[-24.3] y_diff:[0.156] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-19.905] y_diff:[0.236] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_850.pth] saved.
# [900/2500][36.0%]
#   reward:[11.9] y_diff:[0.584] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-6.711] y_diff:[0.468] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_900.pth] saved.
# [950/2500][38.0%]
#   reward:[-2.5] y_diff:[0.442] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-30.401] y_diff:[0.461] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_950.pth] saved.
# [1000/2500][40.0%]
#   reward:[-8.1] y_diff:[0.350] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[21.515] y_diff:[0.433] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1000.pth] saved.
# [1050/2500][42.0%]
#   reward:[-23.2] y_diff:[0.127] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-8.083] y_diff:[0.130] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1050.pth] saved.
# [1100/2500][44.0%]
#   reward:[11.2] y_diff:[0.572] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[12.564] y_diff:[0.724] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1100.pth] saved.
# [1150/2500][46.0%]
#   reward:[-8.3] y_diff:[-0.060] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[18.121] y_diff:[0.364] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1150.pth] saved.
# [1200/2500][48.0%]
#   reward:[-51.5] y_diff:[0.410] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-41.494] y_diff:[0.406] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1200.pth] saved.
# [1250/2500][50.0%]
#   reward:[19.4] y_diff:[0.723] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[16.307] y_diff:[0.896] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1250.pth] saved.
# [1300/2500][52.0%]
#   reward:[-24.0] y_diff:[0.852] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[18.106] y_diff:[0.481] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1300.pth] saved.
# [1350/2500][54.0%]
#   reward:[-578.4] y_diff:[0.103] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-198.274] y_diff:[0.059] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1350.pth] saved.
# [1400/2500][56.0%]
#   reward:[24.0] y_diff:[1.341] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[66.075] y_diff:[1.356] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1400.pth] saved.
# [1450/2500][58.0%]
#   reward:[-31.0] y_diff:[0.085] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-54.426] y_diff:[0.055] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1450.pth] saved.
# [1500/2500][60.0%]
#   reward:[63.2] y_diff:[1.313] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[59.890] y_diff:[1.198] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1500.pth] saved.
# [1550/2500][62.0%]
#   reward:[64.0] y_diff:[1.655] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[15.408] y_diff:[1.494] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1550.pth] saved.
# [1600/2500][64.0%]
#   reward:[41.4] y_diff:[1.726] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[81.454] y_diff:[1.712] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1600.pth] saved.
# [1650/2500][66.0%]
#   reward:[96.8] y_diff:[2.046] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[90.578] y_diff:[2.035] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1650.pth] saved.
# [1700/2500][68.0%]
#   reward:[113.2] y_diff:[2.381] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[101.836] y_diff:[2.288] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1700.pth] saved.
# [1750/2500][70.0%]
#   reward:[108.8] y_diff:[2.395] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[120.035] y_diff:[2.548] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1750.pth] saved.
# [1800/2500][72.0%]
#   reward:[-12.6] y_diff:[0.075] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-17.124] y_diff:[0.035] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1800.pth] saved.
# [1850/2500][74.0%]
#   reward:[90.1] y_diff:[2.616] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[123.458] y_diff:[2.639] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1850.pth] saved.
# [1900/2500][76.0%]
#   reward:[87.1] y_diff:[2.281] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[67.472] y_diff:[2.043] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1900.pth] saved.
# [1950/2500][78.0%]
#   reward:[4.1] y_diff:[0.031] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[8.065] y_diff:[0.039] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_1950.pth] saved.
# [2000/2500][80.0%]
#   reward:[90.5] y_diff:[2.491] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[94.525] y_diff:[2.151] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2000.pth] saved.
# [2050/2500][82.0%]
#   reward:[75.1] y_diff:[2.292] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[119.744] y_diff:[2.531] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2050.pth] saved.
# [2100/2500][84.0%]
#   reward:[125.9] y_diff:[2.912] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[90.864] y_diff:[2.436] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2100.pth] saved.
# [2150/2500][86.0%]
#   reward:[-0.9] y_diff:[0.023] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-2.716] y_diff:[0.028] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2150.pth] saved.
# [2200/2500][88.0%]
#   reward:[108.6] y_diff:[2.504] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[125.414] y_diff:[2.723] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2200.pth] saved.
# [2250/2500][90.0%]
#   reward:[88.0] y_diff:[2.607] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[103.587] y_diff:[2.477] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2250.pth] saved.
# [2300/2500][92.0%]
#   reward:[117.7] y_diff:[2.518] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[111.546] y_diff:[2.692] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2300.pth] saved.
# [2350/2500][94.0%]
#   reward:[100.2] y_diff:[2.209] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[112.876] y_diff:[2.639] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2350.pth] saved.
# [2400/2500][96.0%]
#   reward:[84.2] y_diff:[2.019] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[127.360] y_diff:[2.634] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2400.pth] saved.
# [2450/2500][98.0%]
#   reward:[-27.9] y_diff:[0.038] epi_len:[61/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[-51.168] y_diff:[-0.047] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2450.pth] saved.
# [2500/2500][100.0%]
#   reward:[110.2] y_diff:[2.454] epi_len:[249/250] buffer_size:[50000] alpha:[0.00]
#   [Eval] reward:[113.288] y_diff:[2.452] epi_len:[249/250]
#   [Save] [./result/weights/sac_snapbot_running/episode_2500.pth] saved.
# Done.
